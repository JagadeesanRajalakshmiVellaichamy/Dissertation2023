# %% [markdown]
# # YOUTUBE DATA API V3 - DEVELOPER ACCOUNT
# #https://console.cloud.google.com/apis/library/youtube.googleapis.com

# %%
pip install google-api-python-client

# %%
from googleapiclient.discovery import build
import googleapiclient.errors

#Token and authentication
API_TOKEN = "AIzaSyDPkNg5OIyRc2M3i2eOyR8hMvU5MTH-N7U"
yt = build('youtube', 'v3', developerKey=API_TOKEN)

try:
    #Query build on elections in Tamil which extract video ids to search for comments
    search_response = yt.search().list(
        q='பிரதமர் தேர்தல் 2019',
        part='snippet',
        type='video',
        regionCode='IN',#Region
        relevanceLanguage='ta',#Language
        maxResults=50  #
    ).execute()

    video_ids = []
    for search_result in search_response.get('items', []):
        video_ids.append(search_result['id']['videoId'])

#Get comments for each video_id retrived via api
    for video_id in video_ids:
        comment_response = yt.commentThreads().list(
            part='snippet',
            videoId=video_id,
            textFormat='plainText',
            maxResults=100 #number of comments per video
        ).execute()

        for comment_result in comment_response.get('items', []):
            comment = comment_result['snippet']['topLevelComment']['snippet']['textDisplay']
            print(comment)

except googleapiclient.errors.HttpError as e:
    print("An error occurred:", e)
# Out:
# modi jhumle baaj baateye badi badi hall Macha do bs krna kuch nahi hota jhumle bolo feku modi Wrestlers k sath kya hora pura desh dekhra Kisaan andoln ne modi ki band baja di thi adani k fyda k liye laaya tha wo kale kanoon.Rahul gandhi ji ne adani pe bola modi ki fatt k hath mai aagi thabhi rahul gandhi ki sadsyeta khatam krdi taaki dubara parliament mai b nahi inflation unemployment china andr ghusra hai mehangaayi chothe bacho ki chizo pe taak GST laga diya galat decsions Note bandi Manipur jalra jaha kuch ni bolega bs Jhumle fanko Andbhakat aise whatsapp university k data pe trsut krte gai Jo modi ki IT marketing cells hi fake banati hai
# ab sab ulta hone wala hai, 2024 me log sab dekh Rahe h modi ji🙏🙏🙏 Jo Maharashtra me aapne rajniti kiya
# Modi chor hai
# Always modi ji❤❤
# I give vote to bjp because I hate congress
# During Congress time if you think you born as hindu .....
# You are a rapist , you are a criminal ,
# You are terrorist ....😁
#
#
# I hate congress
# Only
# ...
